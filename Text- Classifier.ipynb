# %% [markdown]
# # workshop 6

# %% [markdown]
# Name: Yajing Zhou,  Michael Uzoma

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
import gensim
import pandas as pd
import numpy as np
import os
from sklearn.linear_model import LogisticRegressionCV, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.metrics import confusion_matrix, accuracy_score
import re

# %%
stopwords = set(stopwords.words('english'))

# %%
def read_directory(directory):
    """
    Lists all file paths from given directory
    """

    ret_val = []
    for file in os.listdir(directory):
        if file.endswith(".txt"):
            ret_val.append(str(directory) + "/" + str(file))
    return ret_val

# %%
def read_file(path):
    """
    Reads all lines from file on given path
    """

    f = open(path, "r")
    read = f.readlines()
    ret_val = []
    for line in read:
        if line.startswith("#"):
            pass
        else:
            ret_val.append(line)
    return ret_val

# %%
def read_line(line):
    """
    Returns sentence category and sentence in given line
    """

    splits = []
    s_category = ""
    sentence = ""
    if "\t" in line:
        splits = line.split("\t")
        s_category = splits[0]
        sentence = splits[1].lower()
    else:
        splits = line.split(" ")
        s_category = splits[0]
        sentence = line[len(s_category)+1:].lower()

    sentence = " ".join([word for word in word_tokenize(sentence) if word not in stopwords])
    # for sw in stopwords:
    #     sentence = sentence.replace(sw, "")
    pattern = re.compile("[^\w']")
    sentence = pattern.sub(' ', sentence) # Any non-characters (here ^ is for negation and not for the start) replace with white space
    sentence = re.sub(' +', ' ', sentence) # If more than one spaces, make them just one space
    return s_category, sentence

# %%
def read_traindata(input_folder):
    """
    Maps each sentence to it's category
    """

    test_folder = read_directory(input_folder)
    t_sentences = []
    t_categories = []
    for file in test_folder:
        lines = read_file(file)
        for line in lines:
            c, s = read_line(line)
            if s.endswith('\n'):
                s = s[:-1]
            t_sentences.append(s)
            t_categories.append(c)
    return t_categories, t_sentences

# %%
categories, sentence = read_traindata('labeled_dataset')

# %%
sentence
# Out:
# ['although internet level topology extensively studied past years little known details taxonomy',
#  'node represent wide variety organizations e g large isp small private business university vastly different network characteristics external connectivity patterns network growth tendencies properties hardly neglect working veracious internet representations simulation environments',
#  'paper introduce radically new approach based machine learning techniques map ases internet natural taxonomy',
#  'successfully classify number number percent ases expected accuracy number number percent',
#  'release community level topology dataset augmented number taxonomy information number set attributes used classify ases',
#  'believe dataset serve invaluable addition understanding structure evolution internet',
#  'rapid expansion internet last two decades produced large scale system thousands diverse independently managed networks collectively provide global connectivity across wide spectrum geopolitical environments',
#  'number number number globally routable identifiers increased less number number number number exerting significant pressure interdomain routing well functional structural parts internet',
#  'impressive growth resulted heterogenous highly complex system challenges accurate realistic modeling internet infrastructure',
#  'particular level topology intermix networks owned operated many different organizations e g backbone providers regional providers access providers universities private companies',
#  'statistical information faithfully characterizes different types critical path toward understanding structure internet well modeling topology growth',
#  'topology modeling knowledge types mandatory augmenting synthetically constructed measured topologies realistic intra inter router level topologies',
#  'example expect network dual homed university drastically different dual homed small company',
#  'university likely contain dozens internal routers thousands hosts many network elements switches servers firewalls',
#  'hand small company probably single router simple network topology',
#  'since diversity among different network types accurately augment level topology appropriate router level topologies misc',
#  'moreover annotating ases topology types prerequisite modeling evolution internet since different types ases exhibit different growth patterns',
#  'example internet service providers isp grow attracting new customers engaging business agreements isps',
#  'hand small companies connect internet one isps grow significantly time',
#  'thus categorizing different types ases internet necessary identify network evolution patterns develop accurate evolution models',
#  'taxonomy also necessary mapping ip addresses different types users',
#  'example traffic analysis studies often required distinguish packets come home business users',
#  'given taxonomy possible realize goal checking type originates prefix ip address lies',
#  'work introduce radically new approach based machine learning construct representative taxonomy',
#  'develop algorithm classify ases based empirically observed differences characteristics',
#  'use large set data internet routing registries irr citation routeviews citation identify intrinsic differences ases different types',
#  'employ novel machine learning technique build classification algorithm exploits differences classify ases six representative classes reflect ases different network properties infrastructures',
#  'derive macroscopic statistics different types ases internet validate results using sample number manually identified types',
#  'validation demonstrates classification algorithm achieves high accuracy number number percent examined classifications correct',
#  'finally make results classifier publicly available promote research understanding internet structure evolution',
#  'section start brief discussion related work',
#  'section describes data used section specify set classes use experiments',
#  'section introduces classification approach results',
#  'validate section conclude section',
#  'although internet level topology extensively studied past years little known details taxonomy',
#  'node represent wide variety organizations e g large isp small private business university vastly different network characteristics external connectivity patterns network growth tendencies properties hardly neglect working veracious internet representations simulation environments',
#  'paper introduce radically new approach based machine learning techniques map ases internet natural taxonomy',
#  'successfully classify number number percent ases expected accuracy number number percent',
#  'release community level topology dataset augmented number taxonomy information number set attributes used classify ases',
#  'believe dataset serve invaluable addition understanding structure evolution internet',
#  'rapid expansion internet last two decades produced large scale system thousands diverse independently managed networks collectively provide global connectivity across wide spectrum geopolitical environments',
#  'number number number globally routable identifiers increased less number number number number exerting significant pressure interdomain routing well functional structural parts internet',
#  'impressive growth resulted heterogenous highly complex system challenges accurate realistic modeling internet infrastructure',
#  'particular level topology intermix networks owned operated many different organizations e g backbone providers regional providers access providers universities private companies',
#  'statistical information faithfully characterizes different types critical path toward understanding structure internet well modeling topology growth',
#  'topology modeling knowledge types mandatory augmenting synthetically constructed measured topologies realistic intra inter router level topologies',
#  'example expect network dual homed university drastically different dual homed small company',
#  'university likely contain dozens internal routers thousands hosts many network elements switches servers firewalls',
#  'hand small company probably single router simple network topology',
#  'since diversity among different network types accurately augment level topology appropriate router level topologies characterize composing ases',
#  'moreover annotating ases topology types prerequisite modeling evolution internet since different types ases exhibit different growth patterns',
#  'example internet service providers isp grow attracting new customers engaging business agreements isps',
#  'hand small companies connect internet one isps grow significantly time',
#  'thus categorizing different types ases internet necessary identify network evolution patterns develop accurate evolution models',
#  'taxonomy also necessary mapping ip addresses different types users',
#  'example traffic analysis studies often required distinguish packets come home business users',
#  'given taxonomy possible realize goal checking type originates prefix ip address lies',
#  'work introduce radically new approach based machine learning construct representative taxonomy',
#  'develop algorithm classify ases based empirically observed differences characteristics',
#  'use large set data internet routing registries irr citation routeviews citation identify intrinsic differences ases different types',
#  'employ novel machine learning technique build classification algorithm exploits differences classify ases six representative classes reflect ases different network properties infrastructures',
#  'derive macroscopic statistics different types ases internet validate results using sample number manually identified types',
#  'validation demonstrates classification algorithm achieves high accuracy number number percent examined classifications correct',
#  'finally make results classifier publicly available promote research understanding internet structure evolution',
#  'section start brief discussion related work',
#  'section describes data used section specify set classes use experiments',
#  'section introduces classification approach results',
#  'validate section conclude section',
#  'although internet as level topology extensively studied past years little known details taxonomy',
#  " node '' represent wide variety organizations e g large isp small private business university vastly different network characteristics external connectivity patterns network growth tendencies properties hardly neglect working veracious internet representations simulation environments",
#  'paper introduce radically new approach based machine learning techniques map ases internet natural taxonomy',
#  'successfully classify 95 3 ases expected accuracy 78 1 ',
#  'release community as level topology dataset augmented 1 taxonomy information 2 set attributes used classify ases',
#  'believe dataset serve invaluable addition understanding structure evolution internet',
#  'rapid expansion internet last two decades produced large scale system thousands diverse independently managed networks collectively provide global connectivity across wide spectrum geopolitical environments',
#  '1997 2005 number globally routable identifiers increased less 2 000 20 000 exerting significant pressure interdomain routing well functional structural parts internet',
#  'impressive growth resulted heterogenous highly complex system challenges accurate realistic modeling internet infrastructure',
#  'particular as level topology intermix networks owned operated many different organizations e g backbone providers regional providers access providers universities private companies',
#  'statistical information faithfully characterizes different types critical path toward understanding structure internet well modeling topology growth',
#  'topology modeling knowledge types mandatory augmenting synthetically constructed measured topologies realistic intra as inter as router level topologies',
#  'example expect network dual homed university drastically different dual homed small company',
#  'university likely contain dozens internal routers thousands hosts many network elements switches servers firewalls ',
#  'hand small company probably single router simple network topology',
#  'since diversity among different network types accurately augment as level topology appropriate router level topologies characterize composing ases',
#  'moreover annotating ases topology types prerequisite modeling evolution internet since different types ases exhibit different growth patterns',
#  'example internet service providers isp grow attracting new customers engaging business agreements isps',
#  'hand small companies connect internet one isps grow significantly time',
#  'thus categorizing different types ases internet necessary identify network evolution patterns develop accurate evolution models',
#  'taxonomy also necessary mapping ip addresses different types users',
#  'example traffic analysis studies often required distinguish packets come home business users',
#  'given taxonomy possible realize goal checking type originates prefix ip address lies',
#  'work introduce radically new approach based machine learning construct representative taxonomy',
#  'develop algorithm classify ases based empirically observed differences characteristics',
#  'use large set data internet routing registries irr citation routeviews citation identify intrinsic differences ases different types',
#  ' employ novel machine learning technique build classification algorithm exploits differences classify ases six representative classes reflect ases different network properties infrastructures',
#  'derive macroscopic statistics different types ases internet validate results using sample of 1200 manually identified types',
#  'validation demonstrates classification algorithm achieves high accuracy 78 1 examined classifications correct',
#  "finally make results classifier publicly available promote research understanding internet 's structure evolution",
#  'section start brief discussion related work',
#  'section describes data used section specify set classes use experiments',
#  'section introduces classification approach results',
#  'validate section conclude section ',
#  'paper derive equations loop corrected belief propagation continuous variable gaussian model',
#  'using exactness averages belief propagation gaussian models different way obtaining covariances found based belief propagation cavity graphs',
#  'discuss relation loop correction algorithm expectation propagation algorithms case model longer gaussian slightly perturbed nonlinear terms',
#  'message passing techniques graphical models allow computation approximate marginal probabilities time interval scaling polynomially model size',
#  'discovery consequently revolutionized several fields applications past years error correcting codes vision probably prominent examples',
#  'many cases corresponding graphs loopy implying either error resulting application loopy belief propagation bp negligible particular model tolerated particular purpose bp serves',
#  'cases sophisticated refinements bp necessary taking account part loop errors',
#  'finding optimal treatment loop errors motivates active field research different solutions applying different model classes developed',
#  'models involving many short loops like regular lattices cvm type approaches work well citation tree ep approaches citation',
#  'latter may also applied correct incidental large loop',
#  'unifying frameworks like region graphs citation lead general strategies selecting basic clusters underlying approaches general model classes',
#  'recent analysis shown local update equations bp may interpreted zero order term expansion cavity connected correlations',
#  'quantities parameterizations cavity distributions e distribution neighbor variables central variable removed graph',
#  'bethe approximation bp recovered cavity distribution assumed factorize whereas first order correction local update equations obtained one takes account pair cumulants citation',
#  'estimation pair cumulants possible extra runs bp allowing new polynomial time algorithms reducing errors order applying algorithms running time scales extra factor citation',
#  'although scaling seems heavy large benefit approach require selection basic clusters underlying tree structures since takes account effect loops contribute nontrivial correlations cavity distribution',
#  'loop correction strategy applicable class models perturbative expansion around bethe approximation makes sense e models large loops relatively weak interactions',
#  'principal requirement magnitude pair variable cumulants cavity distributions order smaller single variable cumulants third order cumulants even smaller etc',
#  'however heuristics based strategy allow good algorithms performing well outside parameter regimes citation',
#  'far approach developed discrete variable models abstract citation versus practical level citation',
#  'paper apply idea graphical models continuous variables',
#  'derive loop corrected belief propagation equations simple tractable gaussian models yielding message passing scheme besides correct average marginals also yields correct variances',
#  'besides discuss approaches potentially applicable cases extra function approximations necessary relation expectation propagation',
#  'product loop corrected belief propagation equations algorithm calculates exact covariance matrices gaussian models like one discussed citation without explicitly using linear response',
#  'paper derive equations loop corrected belief propagation continuous variable gaussian model',
#  'using exactness averages belief propagation gaussian models different way obtaining covariances found based belief propagation cavity graphs',
#  'discuss relation loop correction algorithm expectation propagation algorithms case model longer gaussian slightly perturbed nonlinear terms',
#  'message passing techniques graphical models allow computation approximate marginal probabilities time interval scaling polynomially model size',
#  'discovery consequently revolutionized several fields applications past years error correcting codes vision probably prominent examples',
#  'many cases corresponding graphs loopy implying either error resulting application loopy belief propagation bp negligible particular model tolerated particular purpose bp serves',
#  'cases sophisticated refinements bp necessary taking account part loop errors',
#  "finding optimal treatment loop errors '' motivates active field research different solutions applying different model classes developed",
#  'models involving many short loops like regular lattices cvm type approaches work well citation tree ep approaches citation',
#  'latter may also applied correct incidental large loop',
#  'unifying frameworks like region graphs citation lead general strategies selecting basic clusters underlying approaches general model classes',
#  "recent analysis shown local update equations bp may interpreted zero order term expansion cavity connected correlations ''",
#  "quantities parameterizations cavity distributions '' e distribution neighbor variables central variable removed graph",
#  'bethe approximation bp recovered cavity distribution assumed factorize whereas first order correction local update equations obtained one takes account pair cumulants citation',
#  'estimation pair cumulants possible extra runs bp allowing new polynomial time algorithms reducing errors order symbol applying algorithms running time scales extra factor symbol citation',
#  'although scaling seems heavy large benefit approach require selection basic clusters underlying tree structures since takes account effect loops contribute nontrivial correlations cavity distribution',
#  " loop correction '' strategy applicable class models perturbative expansion around bethe approximation makes sense e models large loops relatively weak interactions",
#  'principal requirement magnitude pair variable cumulants cavity distributions order smaller single variable cumulants third order cumulants even smaller etc',
#  'however heuristics based strategy allow good algorithms performing well outside parameter regimes citation',
#  'far approach developed discrete variable models abstract citation versus practical level citation',
#  'paper apply idea graphical models continuous variables',
#  'derive loop corrected belief propagation equations simple tractable gaussian models yielding message passing scheme besides correct average marginals also yields correct variances',
#  'besides discuss approaches potentially applicable cases extra function approximations necessary relation expectation propagation',
#  'by product loop corrected belief propagation equations algorithm calculates exact covariance matrices gaussian models like one discussed citation without explicitly using linear response',
#  'defensive forecasting method transforming laws probability stated game theoretic terms strategies sceptic forecasting algorithms',
#  "two known varieties defensive forecasting continuous '' sceptic 's moves assumed depend forecasts semi continuous manner produces deterministic forecasts randomized '' dependence sceptic 's moves forecasts arbitrary forecaster 's moves allowed randomized",
#  "note shows randomized variety obtained continuous variety smearing sceptic 's moves make continuous",
#  'new compared version 1 17 august 2007 report assumption version 1 outcome space symbol finite relaxed assumed compact',
#  'case symbol finite shown forecaster choose randomized forecasts concentrated finite set cardinality symbol',
#  'continuous variety defensive forecasting essentially introduced levin citation later rediscovered kakade foster citation takemura et al citation',
#  "randomized variety introduced case von mises 's version game theoretic approach probability foster vohra citation developed among others sandroni et al citation papers however concerned asymptotic calibration",
#  'non asymptotic versions randomized variety proposed sandroni citation based standard measure theoretic probability vovk shafer citation based game theoretic probability ',
#  'kakade foster citation noticed calibration results require little randomization important aspect theorem ',
#  'note states two simple results defensive forecasting theorem continuous variety theorem randomized variety',
#  "proof theorem obtained proof theorem blurring sceptic 's moves",
#  'informal discussions assuming set symbol possible outcomes finite although try make mathematical statements general possible',
#  'reader interested main ideas might choose specialize theorems proofs case finite symbol',
#  'generalization bounds learning theory based measure complexity hypothesis class used independently algorithm',
#  'contrast notion algorithmic stability used derive tight generalization bounds tailored specific learning algorithms exploiting particular properties',
#  'however much learning theory existing stability analyses bounds apply scenario samples independently identically distributed',
#  'many machine learning applications however assumption hold',
#  'observations received learning algorithm often inherent temporal dependence',
#  'paper studies scenario observations drawn stationary mixing mixing sequence widely adopted assumption study non independent identically distributed processes implies dependence observations weakening time',
#  'prove novel distinct stability based generalization bounds stationary mixing mixing sequences',
#  'bounds strictly generalize bounds given independent identically distributed case apply stable learning algorithms thereby extending use stability bounds non independent identically distributed scenarios',
#  'also illustrate application mixing generalization bounds general classes learning algorithms including support vector regression kernel ridge regression support vector machines many kernel regularization based relative entropy based regularization algorithms',
#  'novel bounds thus viewed first theoretical basis use algorithms non independent identically distributed scenarios',
#  'generalization bounds learning theory based measure complexity hypothesis class used vc dimension covering numbers rademacher complexity',
#  'measures characterize class hypotheses independently algorithm',
#  'contrast notion algorithmic stability used derive bounds tailored specific learning algorithms exploit particular properties',
#  'learning algorithm stable hypothesis outputs varies limited way response small changes made training set',
#  'algorithmic stability used effectively past derive tight generalization bounds citation',
#  'much learning theory existing stability analyses bounds apply scenario samples independently identically distributed independent identically distributed',
#  'many machine learning applications assumption however hold fact independent identically distributed assumption tested derived data analysis',
#  'observations received learning algorithm often inherent temporal dependence',
#  'clear system diagnosis time series prediction problems',
#  'clearly prices different stocks day stock different days may dependent',
#  'less apparent time dependency may affect data sampled many tasks well',
#  'paper studies scenario observations drawn stationary mixing mixing sequence widely adopted assumption study non independent identically distributed processes implies dependence observations weakening time citation',
#  'prove novel distinct stability based generalization bounds stationary mixing mixing sequences',
#  'bounds strictly generalize bounds given independent identically distributed case apply stable learning algorithms thereby extending usefulness stability bounds non independent identically distributed scenarios',
#  'proofs based independent block technique described citation attributed citation commonly used contexts',
#  'however analysis differs previous uses technique blocks points considered equal size',
#  'analysis stationary mixing sequences make use generalized version mcdiarmid inequality citation holds mixing sequences',
#  'leads stability based generalization bounds standard exponential form',
#  'generalization bounds stationary mixing sequences cover general non independent identically distributed scenario use standard mcdiarmid inequality however unlike mixing case mixing bound presented purely exponential bound contains additive term depending mixing coefficient',
#  'also illustrate application mixing generalization bounds general classes learning algorithms including support vector regression svr citation kernel ridge regression citation support vector machines svms citation',
#  'algorithms support vector regression svr citation used context time series prediction independent identically distributed assumption hold good experimental results citation',
#  'knowledge use algorithms non independent identically distributed scenarios previously supported theoretical analysis',
#  'stability bounds give svr svms many kernel regularization based relative entropy based regularization algorithms thus viewed first theoretical basis use scenarios',
#  'following sections organized follows',
#  'section introduce necessary definitions non independent identically distributed problems considering discuss learning scenarios context',
#  'section gives main generalization bounds stationary mixing sequences based stability well illustration applications general kernel regularization based algorithms including svr krr svms well relative entropy based regularization algorithms',
#  'finally section presents first known stability bounds general stationary mixing scenario',
#  'generalization bounds learning theory based measure complexity hypothesis class used independently algorithm',
#  'contrast notion algorithmic stability used derive tight generalization bounds tailored specific learning algorithms exploiting particular properties',
#  'however much learning theory existing stability analyses bounds apply scenario samples independently identically distributed',
#  'many machine learning applications however assumption hold',
#  'observations received learning algorithm often inherent temporal dependence',
#  'paper studies scenario observations drawn stationary symbol mixing symbol mixing sequence widely adopted assumption study non iid processes implies dependence observations weakening time',
#  'prove novel distinct stability based generalization bounds stationary symbol mixing symbol mixing sequences',
#  'bounds strictly generalize bounds given iid case apply stable learning algorithms thereby extending use stability bounds non iid scenarios',
#  'also illustrate application symbol mixing generalization bounds general classes learning algorithms including support vector regression kernel ridge regression support vector machines many kernel regularization based relative entropy based regularization algorithms',
#  'novel bounds thus viewed first theoretical basis use algorithms non iid scenarios',
#  'generalization bounds learning theory based measure complexity hypothesis class used vc dimension covering numbers rademacher complexity',
#  'measures characterize class hypotheses independently algorithm',
#  'contrast notion algorithmic stability used derive bounds tailored specific learning algorithms exploit particular properties',
#  'learning algorithm stable hypothesis outputs varies limited way response small changes made training set',
#  'algorithmic stability used effectively past derive tight generalization bounds citation',
#  ' much learning theory existing stability analyses bounds apply scenario samples independently identically distributed iid ',
#  'many machine learning applications assumption however hold fact iid assumption tested derived data analysis',
#  'observations received learning algorithm often inherent temporal dependence',
#  'clear system diagnosis time series prediction problems',
#  'clearly prices different stocks day stock different days may dependent',
#  ' less apparent time dependency may affect data sampled many tasks well',
#  'paper studies scenario observations drawn stationary symbol mixing symbol mixing sequence widely adopted assumption study non iid processes implies dependence observations weakening time citation',
#  'prove novel distinct stability based generalization bounds stationary symbol mixing symbol mixing sequences',
#  'bounds strictly generalize bounds given iid case apply stable learning algorithms thereby extending usefulness stability bounds non iid scenarios',
#  'proofs based independent block technique described citation attributed citation commonly used contexts',
#  'however analysis differs previous uses technique blocks points considered equal size',
#  "analysis stationary symbol mixing sequences make use generalized version mcdiarmid 's inequality citation holds symbol mixing sequences",
#  'leads stability based generalization bounds standard exponential form',
#  "generalization bounds stationary symbol mixing sequences cover general non iid scenario use standard mcdiarmid 's inequality however unlike symbol mixing case symbol mixing bound presented purely exponential bound contains additive term depending mixing coefficient",
#  'also illustrate application symbol mixing generalization bounds general classes learning algorithms including support vector regression svr citation kernel ridge regression citation support vector machines svms citation',
#  'algorithms support vector regression svr citation used context time series prediction iid assumption hold good experimental results citation',
#  'knowledge use algorithms non iid scenarios previously supported theoretical analysis',
#  'stability bounds give svr svms many kernel regularization based relative entropy based regularization algorithms thus viewed first theoretical basis use scenarios',
#  'following sections organized follows',
#  'section introduce necessary definitions non iid problems considering discuss learning scenarios context',
#  'section gives main generalization bounds stationary symbol mixing sequences based stability well illustration applications general kernel regularization based algorithms including svr krr svms well relative entropy based regularization algorithms',
#  'finally section presents first known stability bounds general stationary symbol mixing scenario',
#  'generalization bounds learning theory based measure complexity hypothesis class used independently algorithm',
#  'contrast notion algorithmic stability used derive tight generalization bounds tailored specific learning algorithms exploiting particular properties',
#  'however much learning theory existing stability analyses bounds apply scenario samples independently identically distributed',
#  'many machine learning applications however assumption hold',
#  'observations received learning algorithm often inherent temporal dependence',
#  'paper studies scenario observations drawn stationary symbol mixing symbol mixing sequence widely adopted assumption study non iid processes implies dependence observations weakening time',
#  'prove novel distinct stability based generalization bounds stationary symbol mixing symbol mixing sequences',
#  'bounds strictly generalize bounds given iid case apply stable learning algorithms thereby extending use stability bounds non iid scenarios',
#  'also illustrate application symbol mixing generalization bounds general classes learning algorithms including support vector regression kernel ridge regression support vector machines many kernel regularization based relative entropy based regularization algorithms',
#  'novel bounds thus viewed first theoretical basis use algorithms non iid scenarios',
#  'generalization bounds learning theory based measure complexity hypothesis class used vc dimension covering numbers rademacher complexity',
#  'measures characterize class hypotheses independently algorithm',
#  'contrast notion algorithmic stability used derive bounds tailored specific learning algorithms exploit particular properties',
#  'learning algorithm stable hypothesis outputs varies limited way response small changes made training set',
#  'algorithmic stability used effectively past derive tight generalization bounds citation',
#  ' much learning theory existing stability analyses bounds apply scenario samples independently identically distributed iid ',
#  'many machine learning applications assumption however hold fact iid assumption tested derived data analysis',
#  'observations received learning algorithm often inherent temporal dependence',
#  'clear system diagnosis time series prediction problems',
#  'clearly prices different stocks day stock different days may dependent',
#  ' less apparent time dependency may affect data sampled many tasks well',
#  'paper studies scenario observations drawn stationary symbol mixing symbol mixing sequence widely adopted assumption study non iid processes implies dependence observations weakening time citation',
#  'prove novel distinct stability based generalization bounds stationary symbol mixing symbol mixing sequences',
#  'bounds strictly generalize bounds given iid case apply stable learning algorithms thereby extending usefulness stability bounds non iid scenarios',
#  'proofs based independent block technique described citation attributed citation commonly used contextsmisc',
#  'however analysis differs previous uses technique blocks points considered equal size',
#  "analysis stationary symbol mixing sequences make use generalized version mcdiarmid 's inequality citation holds symbol mixing sequences",
#  'leads stability based generalization bounds standard exponential form',
#  "generalization bounds stationary symbol mixing sequences cover general non iid scenario use standard mcdiarmid 's inequality however unlike symbol mixing case symbol mixing bound presented purely exponential bound contains additive term depending mixing coefficient",
#  'also illustrate application symbol mixing generalization bounds general classes learning algorithms including support vector regression svr citation kernel ridge regression citation support vector machines svms citation',
#  'algorithms support vector regression svr citation used context time series prediction iid assumption hold good experimental results citation',
#  'knowledge use algorithms non iid scenarios previously supported theoretical analysis',
#  'stability bounds give svr svms many kernel regularization based relative entropy based regularization algorithms thus viewed first theoretical basis use scenarios',
#  'following sections organized follows',
#  'section introduce necessary definitions non iid problems considering discuss learning scenarios context',
#  'section gives main generalization bounds stationary symbol mixing sequences based stability well illustration applications general kernel regularization based algorithms including svr krr svms well relative entropy based regularization algorithms',
#  'finally section presents first known stability bounds general stationary symbol mixing scenario',
#  'paper studies quantum annealing qa clustering seen extension simulated annealing sa',
#  'derive qa algorithm clustering propose annealing schedule crucial practice',
#  'experiments show proposed qa algorithm finds better clustering assignments sa',
#  'furthermore qa easy sa implement',
#  'clustering one popular methods data mining',
#  'typically clustering problems formulated optimization problems solved algorithms example em algorithm convex relaxation',
#  'however clustering typically np hard',
#  'simulated annealing sa citation promising candidate',
#  'citation proved sa able find global optimum slow cooling schedule temperature',
#  'although schedule practice slow clustering large amount data well known sa still finds reasonably good solution even faster schedule citeauthor geman number proposed',
#  'statistical mechanics quantum annealing qa proposed novel alternative sa citation',
#  'qa adds another dimension sa annealing see fig',
#  'thus seen extension sa',
#  'qa succeeded specific problems e g ising model statistical mechanics still unclear qa works better sa general',
#  'actually think qa intuitively helps clustering apply qa clustering procedure derive algorithm',
#  'derived qa algorithm depends definition quantum effect',
#  'propose quantum effect leads search strategy fit clustering',
#  'contribution 1 propose qa based optimization algorithm clustering particular quantum effect clustering good annealing schedule crucial applications 2 experimentally show proposed algorithm optimizes clustering assignments better sa',
#  'also show proposed algorithm easy sa implement',
#  'algorithm propose markov chain monte carlo mcmc sampler call qa st sampler',
#  'explain later naive qa sampler intractable even mcmc',
#  'thus approximate qa suzuki trotter st expansion citation derive tractable sampler qa st sampler',
#  'qa st looks like parallel sas interaction see fig',
#  'beginning annealing process qa st almost sas',
#  'hence qa st finds local optima independently',
#  'annealing process continues interaction fig becomes stronger move states closer',
#  'qa st end picks state lowest energy states final solution',
#  'qa st proposed quantum effect works well clustering',
#  'fig example data points grouped four clusters',
#  'symbol symbol locally optimal globally optimal',
#  'suppose symbol equal two symbol symbol fig correspond symbol symbol fig',
#  'although local optima interaction fig allows search better clustering assignment',
#  'quantum effect defines distance metric clustering assignments',
#  'case proposed locates',
#  'thus interaction gives good chance go makes closer see fig',
#  'proposed algorithm actually finds',
#  'fig example',
#  'however similar situation often occurs clustering',
#  'clustering algorithms cases give almost globally optimal solutions like majority data points well clustered',
#  'thus better clustering assignment constructed picking well clustered data points many sub optimal clustering assignments',
#  'note assignment constructed way located sub optimal ones proposed quantum effect qa st find better assignment sub optimal ones']

# %%
df = pd.DataFrame(
data = {
    'categories':categories,
    'sentence':sentence
})
df
# Out:
#     categories                                           sentence
# 0         MISC  although internet level topology extensively s...
# 1         MISC  node represent wide variety organizations e g ...
# 2         AIMX  paper introduce radically new approach based m...
# 3         OWNX  successfully classify number number percent as...
# 4         OWNX  release community level topology dataset augme...
# ..         ...                                                ...
# 310       OWNX                                        fig example
# 311       MISC  however similar situation often occurs clustering
# 312       MISC  clustering algorithms cases give almost global...
# 313       MISC  thus better clustering assignment constructed ...
# 314       MISC  note assignment constructed way located sub op...
#
# [315 rows x 2 columns]

# %%
doc = df.sentence
label = categories

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(doc,label, test_size = 0.33,random_state = 0)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
doc_count = count_vect.fit_transform(doc)
doc_count.shape
# Out:
# (315, 845)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tf_transformer = TfidfTransformer(use_idf = False).fit(doc_count)
doc_tf = tf_transformer.transform(doc_count)
doc_tf.shape
# Out:
# (315, 845)

# %%
tfidf_transformer = TfidfTransformer()

# %%
doc_tfidf = tfidf_transformer.fit_transform(doc_count)
doc_tfidf.shape
# Out:
# (315, 845)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf = MultinomialNB()

# %%
x_clf = clf.fit(doc_tfidf,label)
x_clf
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
def read_line(line):
    """
    Returns sentence category and sentence in given line
    """

    splits = []
    s_category = ""
    sentence = ""
    if "\t" in line:
        splits = line.split("\t")
        
        sentence = splits[0].lower()
    else:
        splits = line.split(" ")
        
        sentence = line.lower()

    sentence = " ".join([word for word in word_tokenize(sentence) if word not in stopwords])
    # for sw in stopwords:
    #     sentence = sentence.replace(sw, "")
    pattern = re.compile("[^\w']")
    sentence = pattern.sub(' ', sentence) # Any non-characters (here ^ is for negation and not for the start) replace with white space
    sentence = re.sub(' +', ' ', sentence) # If more than one spaces, make them just one space
    return sentence

# %%
def read_testdata(input_folder):
    """
    Maps each sentence to it's category
    """

    test_folder = read_directory(input_folder)
    t_sentences = []
    
    for file in test_folder:
        lines = read_file(file)
        for line in lines:
            s = read_line(line)
            
            t_sentences.append(s)
            
    return  t_sentences

# %%
unlabeled = read_testdata('unlabeled_dataset')
unlabeled
# Out:
# ['central problem bioinformatics gene regulation find binding sites regulatory proteins ',
#  'one promising approaches toward identifying short fuzzy sequence patterns comparative analysis orthologous intergenic regions related species ',
#  'analysis complicated various factors ',
#  'first one needs take phylogenetic relationship species account order distinguish conservation due occurrence functional sites spurious conservation due evolutionary proximity ',
#  'second one deal complexities multiple alignments orthologous intergenic regions one consider possibility functional sites may occur outside conserved segments ',
#  'present new motif sampling algorithm phylogibbs runs arbitrary collections multiple local sequence alignments orthologous sequences ',
#  'algorithm searches ways arbitrary number binding sites arbitrary number transcription factors assigned multiple sequence alignments ',
#  'binding site configurations scored bayesian probabilistic model treats aligned sequences model evolution binding sites background intergenic dna ',
#  'model takes phylogenetic relationship species alignment explicitly account ',
#  'algorithm uses simulated annealing monte carlo markov chain sampling rigorously assign posterior probabilities binding sites reports ',
#  'tests synthetic data real data five saccharomyces species algorithm performs significantly better four motif finding algorithms including algorithms also take phylogeny account ',
#  'results also show contrast algorithms phylogibbs make realistic estimates reliability predictions ',
#  "tests suggest running five species multiple alignment single gene 's upstream region phylogibbs average recovers 50 percent binding sites s cerevisiae specificity 50 percent 33 percent binding sites specificity 85 percent ",
#  'also tested phylogibbs collections multiple alignments intergenic regions recently annotated based chip on chip data contain binding sites tf ',
#  "compared phylogibbs 's results previous analysis data using six motif finding algorithms ",
#  '16 21 tfs motif finding methods failed find significant motif phylogibbs recover motif matches literature consensus ',
#  '11 cases disagreement results compiled lists known target genes literature found running phylogibbs regulatory regions yielded binding motif matching literature consensus one cases ',
#  'interestingly literature gene lists little overlap targets annotated based chip on chip data ',
#  'phylogibbs code downloaded link link ',
#  'full set predicted sites tests yeast available link ',
#  'transcription factors proteins bind sequence specific manner short dna segments commonly intergenic dna upstream gene activate suppress gene transcription ',
#  'dna binding domains recognize collections short related dna sequences ',
#  'one generally finds although unique combination bases shared binding sites although different bases occur position clear biases distribution bases occur position binding sites ',
#  'common mathematical representation motif takes variability account so called weight matrix citation citation w whose components w give probabilities finding base c g position binding site ',
#  'main assumption underlying mathematical representation bases occurring different positions binding site probabilistically independent ',
#  'turn follows conditions citation assumption binding energy protein dna sum pairwise contact energies individual nucleotides protein ',
#  'several algorithms based wm representation detect ab initio binding sites common tf collection dna sequences citation citation ',
#  'algorithms broadly fall two classes ',
#  'one class meme citation typical representative searches space wms wm best explain observed sequences ',
#  'class gibbs sampling algorithms gibbs motif sampler citation citation typical representative instead samples space multiple alignments small sequence segments search one likely consist samples common wm ',
#  'crucial factor success ab initio methods ratio number binding sites total amount dna collection sequences ',
#  ' larger number binding sites set smaller total amount dna likely ab initio methods discover binding sites among dna sequences ',
#  'order ensure reasonable chance success one thus needs provide methods collections sequences highly enriched binding sites common tf ',
#  'one possibility use sets upstream regions genes appear co regulated microarray experiments bound common tf chip on chip experiments ',
#  'another possibility use upstream regions orthologous genes related organisms ',
#  'assumption regulation ancestor gene thus binding sites conserved orthologs descend ',
#  'latter approach general complicated number factors ',
#  'searching regulatory sites sequences phylogenetically related upstream regions different genes organism one may simply look short sequence motifs overrepresented among input sequences ',
#  'set species orthologous sequences derive sufficiently diverged one may simply choose ignore phylogenetic relationship sequences treat orthologous sequences way sequences phylogenetically related ',
#  ' instance approach taken mccue et al citation citation gibbs motif sampler algorithm citation citation used upstream regions proteo bacteria ',
#  'however approach applicable datasets containing closely related species sequences exhibit significant amounts similarity simply evolutionary proximity ',
#  'moreover amount similarity depend phylogenetic distance species clear finding conserved sequence motifs orthologous sequences closely related species much less indicative function finding sequence motifs conserved distant species ',
#  'one general thus distinguish conservation due functional constraints conservation due evolutionary proximity correctly phylogenetic relationship sequences taken account ',
#  'second challenge using orthologous intergenic sequences multiple species nontrivial structure multiple alignments ',
#  'one typically finds heterogeneous pattern conservation well conserved blocks different sizes covering different subsets species interspersed sequence segments show little similarity sequences species ',
#  'technique phylogenetic footprinting restricts attention sequence segments genome interest show significant conservation species ',
#  'conserved regions multiple genes searched common motifs variety techniques ',
#  'unclear however extent regulatory sites restricted conserved segments ',
#  'instance several studies drosophila yeast citation citation shown strong correlation experimentally annotated binding sites occur whether region conserved ',
#  'thus least yeast flies considerable information lost focusing conserved regions ',
#  'thus decided retain entire patchwork pattern conserved sequence blocks unaligned segments ',
#  'strategy implemented gibbs sampling approach preliminary account algorithm presented citation ',
#  'algorithm operates arbitrary collections phylogenetically related sequences orthologous intergenic regions sequences phylogenetically related upstream regions different genes organism ',
#  'phylogenetically related groups sequences input pre aligned local multiple alignments clearly similar sequence segments aligned blocks sequence segments marginal similarity left unaligned citation ',
#  'although algorithm also take global multiple alignments input believe often force phylogenetically unrelated segments aligned blocks ',
#  'may adversely affect performance algorithm ',
#  'score putative sites within blocks aligned sequences evolutionary model takes phylogenetic relationships species account putative sites unaligned segments treated independent occurrences ',
#  'bayesian model defines probability distribution arbitrary placements putative binding sites multiple motifs sample monte carlo markov chain ',
#  'first use simulated annealing search globally optimal configuration binding sites ',
#  'motifs configuration tracked sampling run estimate realistic posterior probabilities binding sites algorithm reports ',
#  'recently number algorithms developed search regulatory motifs groups phylogenetically related sequences ',
#  'probably first algorithm proposed generalization consensus algorithm citation called phylocon citation ',
#  'phylocon operates sets co regulated genes orthologs ',
#  'greedy algorithm first finds ungapped alignments similar sequence segments sets orthologous sequences combines alignments different upstream regions larger alignments ',
#  'algorithm take phylogenetic information account i e closely related sequences treated distantly related sequences ',
#  'drawbacks algorithm assumes motif exactly one site intergenic regions assumes site conserved orthologs ',
#  "closely related phylogibbs 's approach two recent algorithms citation citation generalize meme citation take phylogenetic relationships species account ",
#  'main difference emnem phyme phyme uses evolutionary model evolution binding sites phylogibbs takes account binding sites evolve constraints set wm whereas emnem simply assumes overall slower rate evolution binding sites background sequences ',
#  'another difference phyme like phylogibbs treats multiple alignment flexibly emnem demands global multiple alignment ',
#  'main difference phylogibbs algorithms course phylogibbs takes motif sampling approach allows us search multiple motifs parallel whereas phyme emnem use expectation maximization search one wm time ',
#  'following sections first describe bayesian model assigns posterior probability configuration binding sites multiple motifs assigned input sequences ',
#  'start describing model phylogenetically unrelated sequences essentially equivalent model used gibbs motif sampler citation citation describe model extended datasets contain phylogenetically related sequences ',
#  'describe move set search state space possible configurations annealing tracking strategy use identify significant groups sites ',
#  'present examples performance algorithms synthetic real data ',
#  'synthetic datasets consist mixtures wm samples random sequences accordance assumptions algorithms make ',
#  'allows us compare performance algorithms idealized situation contain complexities real data ',
#  'tests also show extent binding sites recovered idealized data function quality wms number sites available number species available phylogenetic distances ',
#  'tests real data use 200 upstream regions saccharomyces cerevisiae known binding sites collection citation compare ability different algorithms recover sites running multiple alignments orthologs upstream regions recently sequenced saccharomyces genomes citation citation ',
#  "finally run phylogibbs collections upstream region alignments annotated citation contain binding sites common tf based data chip on chip experiments extensively compare phylogibbs ' results annotations citation literature "]

# %%
unlabeled_counts = count_vect.transform(unlabeled)

# %%
unlabeled_tfidf = tfidf_transformer.transform(unlabeled_counts)

# %%
predicted = clf.predict(unlabeled_tfidf)
predicted
# Out:
# array(['MISC', 'MISC', 'MISC', 'MISC', 'MISC', 'MISC', 'OWNX', 'MISC',
#        'MISC', 'MISC', 'MISC', 'OWNX', 'OWNX', 'MISC', 'OWNX', 'MISC',
#        'MISC', 'MISC', 'MISC', 'OWNX', 'MISC', 'OWNX', 'MISC', 'MISC',
#        'MISC', 'MISC', 'OWNX', 'OWNX', 'OWNX', 'MISC', 'OWNX', 'MISC',
#        'MISC', 'OWNX', 'OWNX', 'MISC', 'OWNX', 'MISC', 'OWNX', 'MISC',
#        'MISC', 'MISC', 'MISC', 'OWNX', 'MISC', 'OWNX', 'MISC', 'MISC',
#        'MISC', 'OWNX', 'OWNX', 'MISC', 'OWNX', 'MISC', 'MISC', 'MISC',
#        'MISC', 'MISC', 'OWNX', 'MISC', 'OWNX', 'MISC', 'MISC', 'OWNX',
#        'OWNX', 'MISC', 'MISC', 'MISC', 'MISC', 'OWNX', 'OWNX', 'OWNX',
#        'OWNX', 'MISC', 'OWNX', 'MISC', 'OWNX', 'MISC', 'OWNX'],
#       dtype='<U5')

# %%
df2 = pd.DataFrame(
data = {
    'label':predicted,
    'doc':unlabeled
})
df2
# Out:
#    label                                                doc
# 0   MISC  central problem bioinformatics gene regulation...
# 1   MISC  one promising approaches toward identifying sh...
# 2   MISC              analysis complicated various factors
# 3   MISC  first one needs take phylogenetic relationship...
# 4   MISC  second one deal complexities multiple alignmen...
# ..   ...                                                ...
# 74  OWNX  synthetic datasets consist mixtures wm samples...
# 75  MISC  allows us compare performance algorithms ideal...
# 76  OWNX  tests also show extent binding sites recovered...
# 77  MISC  tests real data use 200 upstream regions sacch...
# 78  OWNX  finally run phylogibbs collections upstream re...
#
# [79 rows x 2 columns]

# %%
df2.to_csv('labeled.txt',sep='\t')

# %% [markdown]
# * Summary:
#
# In this workshop, we first read all the documents and then remove the stopwords, and pair the classification with the sentence. Then, we aggregate frequency information for each sentence(document). when we get the counted vectorlist for each sentence, we calculated the tf-idf. At the end we use these data to build our classifier and predicted the unlabeled dataset's label.
#
# In this workshop, we find that the naive bayes is a very easy way for people to prediced the text because it can helps us to classify documents quickly by probability calculation of known data.
